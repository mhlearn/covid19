# %% [markdown]
# # Testing of plotting covid 19 related chart

# %%
# import needed package
import pandas as pd
import numpy as np
import holoviews as hv

# %%
# main MOH path
url = 'https://raw.githubusercontent.com/MoH-Malaysia/covid19-public/main/'

# %%
# import mysejahtera check-in info
mysejahtera = pd.read_csv(url + 'mysejahtera/checkin_malaysia.csv', 
                          parse_dates = ['date'])

# quick view
print(mysejahtera.info())
print(mysejahtera.date.min())
print(mysejahtera.date.max())

# set date index
mysejahtera.set_index('date', inplace=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 237 entries, 0 to 236
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   date        237 non-null    datetime64[ns]
#  1   checkins    237 non-null    int64
#  2   unique_ind  237 non-null    int64
#  3   unique_loc  237 non-null    int64
# dtypes: datetime64[ns](1), int64(3)
# memory usage: 7.5 KB
# None
# 2020-12-01 00:00:00
# 2021-07-25 00:00:00

# %%
mysejahtera.plot.line(figsize=[10,5])
# Out:
# <AxesSubplot:xlabel='date'>

# %%
mysejahtera.loc[(mysejahtera.index.year==2021) & (mysejahtera.index.month>=7)].plot(figsize=[10,5])
# Out:
# <AxesSubplot:xlabel='date'>
